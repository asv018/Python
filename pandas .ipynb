# %%
pip install pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: C:\Users\Arpit\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.7 MB 1.3 MB/s eta 0:00:09
#      --------------------------------------- 0.1/10.7 MB 991.0 kB/s eta 0:00:11
#       --------------------------------------- 0.2/10.7 MB 1.3 MB/s eta 0:00:09
#       --------------------------------------- 0.2/10.7 MB 1.4 MB/s eta 0:00:08
#       --------------------------------------- 0.2/10.7 MB 1.4 MB/s eta 0:00:08
#      - -------------------------------------- 0.5/10.7 MB 1.8 MB/s eta 0:00:06
#      -- ------------------------------------- 0.6/10.7 MB 2.0 MB/s eta 0:00:05
# ...

# %%
import pandas as pd
